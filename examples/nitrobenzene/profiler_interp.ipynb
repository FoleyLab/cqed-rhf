# %%
import pstats

#p = pstats.Stats('output.prof')
#p.sort_stats(pstats.SortKey.CUMULATIVE).print_stats(30) # Prints the top 20 functions sorted by cumulative time

# %%
p = pstats.Stats('output_6311Gs.prof')
p.sort_stats(pstats.SortKey.CUMULATIVE).print_stats(20) # Prints the top 20 functions sorted by cumulative time
# Out:
# Wed Feb 11 08:12:53 2026    output_6311Gs.prof
#
#          9262288 function calls (9089904 primitive calls) in 740.609 seconds
#
#    Ordered by: cumulative time
#    List reduced from 7565 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    1405/1    0.006    0.000  740.623  740.623 {built-in method builtins.exec}
#         1    0.000    0.000  740.623  740.623 ortho_MD_orientation_tracker.py:1(<module>)
#         1    0.010    0.010  739.754  739.754 /Users/jfoley19/Code/cqed-rhf/src/cqed_rhf/drivers.py:38(velocity_verlet_md)
#         3    0.001    0.000  739.743  246.581 /Users/jfoley19/Code/cqed-rhf/src/cqed_rhf/calculator.py:29(energy_and_gradient)
#         3    6.231    2.077  730.028  243.343 /Users/jfoley19/Code/cqed-rhf/src/cqed_rhf/scf.py:48(run)
#      8465    0.055    0.000  683.213    0.081 /Users/jfoley19/miniconda3/envs/psi4_new/lib/python3.11/site-packages/opt_einsum/contract.py:502(contract)
# ...

# %%
p = pstats.Stats('output_6311Gs_opt.prof')
p.sort_stats(pstats.SortKey.CUMULATIVE).print_stats(20)
# Out:
# Wed Feb 11 09:10:21 2026    output_6311Gs_opt.prof
#
#          12903076 function calls (12680669 primitive calls) in 259.803 seconds
#
#    Ordered by: cumulative time
#    List reduced from 7583 to 20 due to restriction <20>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    1403/1    0.006    0.000  259.816  259.816 {built-in method builtins.exec}
#         1    0.000    0.000  259.816  259.816 ortho_opt.py:1(<module>)
#         1    0.000    0.000  258.938  258.938 /Users/jfoley19/Code/cqed-rhf/src/cqed_rhf/drivers.py:209(bfgs_optimize)
#      25/1    0.001    0.000  258.937  258.937 /Users/jfoley19/miniconda3/envs/psi4_new/lib/python3.11/site-packages/scipy/optimize/_minimize.py:53(minimize)
#         1    0.000    0.000  258.937  258.937 /Users/jfoley19/miniconda3/envs/psi4_new/lib/python3.11/site-packages/scipy/optimize/_optimize.py:1328(_minimize_bfgs)
# ...

# %%
p = pstats.Stats('output_sp_6311Gs.prof')
p.sort_stats(pstats.SortKey.CUMULATIVE).print_stats(20)
